# %% [markdown]
# # NLP

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
df = pd.read_csv("spam.csv" , encoding = "latin1")

# %%
df.tail()
# Out:
#         v1                                                 v2 Unnamed: 2  \
# 5567  spam  This is the 2nd time we have tried 2 contact u...        NaN
# 5568   ham              Will Ì_ b going to esplanade fr home?        NaN
# 5569   ham  Pity, * was in mood for that. So...any other s...        NaN
# 5570   ham  The guy did some bitching but I acted like i'd...        NaN
# 5571   ham                         Rofl. Its true to its name        NaN
#
#      Unnamed: 3 Unnamed: 4
# 5567        NaN        NaN
# 5568        NaN        NaN
# 5569        NaN        NaN
# 5570        NaN        NaN
# 5571        NaN        NaN

# %%
df.shape
# Out:
# (5572, 5)

# %%
df.columns
# Out:
# Index(['v1', 'v2', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4'], dtype='object')

# %%
df = df[["v1", "v2"]]

# %%
df.head()
# Out:
#      v1                                                 v2
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %%
df.rename(columns={"v1": "label", "v2":"message"}, inplace = True)

# %%
df.head(2)
# Out:
#   label                                            message
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...

# %%
df.isnull().sum()
# Out:
# label      0
# message    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(403)

# %%
df.drop_duplicates()
# Out:
#      label                                            message
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...
# ...    ...                                                ...
# 5567  spam  This is the 2nd time we have tried 2 contact u...
# 5568   ham              Will Ì_ b going to esplanade fr home?
# 5569   ham  Pity, * was in mood for that. So...any other s...
# 5570   ham  The guy did some bitching but I acted like i'd...
# 5571   ham                         Rofl. Its true to its name
#
# [5169 rows x 2 columns]

# %%
df.duplicated().sum()
# Out:
# np.int64(403)

# %%
print(f"spam message : {(df["label"] == "spam").sum()}")
# Out:
# spam message : 747

# %%
print(f"ham message : {(df["label"] == "ham").sum()}")
# Out:
# ham message : 4825

# %%
print("FREE ENTRY of concert".lower())
# Out:
# free entry of concert

# %%
df["message"] = df["message"].str.lower()

# %%
df.head()
# Out:
#   label                                            message
# 0   ham  go until jurong point, crazy.. available only ...
# 1   ham                      ok lar... joking wif u oni...
# 2  spam  free entry in 2 a wkly comp to win fa cup fina...
# 3   ham  u dun say so early hor... u c already then say...
# 4   ham  nah i don't think he goes to usf, he lives aro...

# %%
import re

# %%
example = "free entry in 2 a weklk !!!! hurrah you won fa tesxt 7354636"

# %%
example_clean = re.sub(r"[^a-z \s]", "", example)

# %%
print(example_clean)
# Out:
# free entry in  a weklk  hurrah you won fa tesxt

# %%
df['message'] = df['message'].apply(lambda x: re.sub(r'[^a-z \s]', '', x))

# %%
df.head()
# Out:
#   label                                            message
# 0   ham  go until jurong point crazy available only in ...
# 1   ham                            ok lar joking wif u oni
# 2  spam  free entry in  a wkly comp to win fa cup final...
# 3   ham        u dun say so early hor u c already then say
# 4   ham  nah i dont think he goes to usf he lives aroun...

# %%
import nltk

# %%
nltk.download("punkt")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\cxash\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\cxash\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
nltk.download("wordnet")
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\cxash\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
from nltk.tokenize import word_tokenize,sent_tokenize

# %%
nltk.download("punkt_tab")
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\cxash\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
sample = "hello all how are you doing today"

# %%
sent_token=sent_tokenize(sample)

# %%
sample_token = word_tokenize(sample)

# %%
nltk.download("punkt_tab")
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\cxash\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
print(sample_token )
# Out:
# ['hello', 'all', 'how', 'are', 'you', 'doing', 'today']

# %%
from nltk.corpus import stopwords

# %%
stopwords = set(stopwords.words('english'))

# %%
df['message'] = df['message'].apply(lambda x : " ".join(
    [words for words in word_tokenize(x) 
     if words not in stopwords]
))

# %%
print(df["message"][2])
# Out:
# free entry wkly comp win fa cup final tkts st may text fa receive entry questionstd txt ratetcs apply overs

# %%
import nltk
from nltk.stem import PorterStemmer

# %%
# Stemmer = PorterStemmer()
stemmer = PorterStemmer()

# %%
# df['message'] = df['message'].apply(
#     lambda x : " ".join([stemmer.stem(word) for word in x.split()])
# )
df['message'] = df['message'].apply(
    lambda x: " ".join([stemmer.stem(word) for word in x.split()])
)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
x = df["message"]

# %%
y = df["label"]

# %%
tfidf = TfidfVectorizer(max_features=3000)

# %%
x_vec = tfidf.fit_transform(x)

# %%
x_vec.shape[1]
# Out:
# 3000

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = X_train, X_test, Y_train, Y_test = train_test_split(
    x_vec,
    y,
    test_size=0.20,
    random_state=42
)

# %%
from sklearn.naive_bayes import MultinomialNB

# %%
model = MultinomialNB()

# %%
model.fit(x_train,y_train)
# Out:
# MultinomialNB()

# %%
y_pred = model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
accuracy = accuracy_score(y_test, y_pred)

# %%
print(accuracy_score)
# Out:
# <function accuracy_score at 0x0000017E41DCECA0>

# %%
cm = confusion_matrix(y_test, y_pred)

# %%
cm
# Out:
# array([[965,   0],
#        [ 26, 124]])

# %%
def predict_message (message):
    msg = message.lower()
    msg = re.sub(r'[^a-z \s]', " ", msg)
    token = word_tokenize(msg)
    token = [w for w in token
            if w not in stopwords]
    tokens = [stemmer.stem(w) for w in token]
    clean_msg = " ".join(tokens)
    vec = tfidf.transform([clean_msg])
    result = model.predict(vec)[0]
    prob= model.predict(vec)[0]
    return result, prob

# %%
text_msg = """congratulations you won a lottery of 100000 rs click on the clink to claim your winning price.

    URgent click the link to claim you Money
    
    """

# %%
predict_message(text_msg)
# Out:
# (np.str_('spam'), np.str_('spam'))
