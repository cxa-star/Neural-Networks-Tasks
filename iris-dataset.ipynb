# %%
import pandas as pd

# %%
df = pd.read_csv("iris.csv")

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
df.shape
# Out:
# (150, 6)

# %%
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
numeric_df =  df.select_dtypes(include=["int64","float64"])
numeric_df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
# [150 rows x 5 columns]

# %%
df.drop_duplicates(df)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
#
# [150 rows x 6 columns]

# %%
df["Species"].value_counts()
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
numeric_col = ['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm']

# %%
for i in numeric_col:
    plt.figure(figsize=(4,2))
    plt.hist(df[i])
    plt.show()

# %%
import seaborn as sns

# %%
sns.pairplot(
    df,
    hue = "Species"
)

# %%
#plt.figure(figsize=(6,4))
#sns.heatmap(
#    df.drop("Id", axis = 1).select_dtypes(include = "float64").corr,
#   annot=True
#)
#plt.show()

# %%
numeric_df = df.drop(["Id","Species"], axis=1)

plt.figure(figsize=(5,4))
sns.heatmap(
    numeric_df.corr(), 
    annot=True
)
plt.show()

# %%
numeric_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SepalLengthCm  150 non-null    float64
#  1   SepalWidthCm   150 non-null    float64
#  2   PetalLengthCm  150 non-null    float64
#  3   PetalWidthCm   150 non-null    float64
# dtypes: float64(4)
# memory usage: 4.8 KB

# %%
print(numeric_df.dtypes)
# Out:
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# dtype: object

# %%
df = df.drop("Id",axis=1)

# %%
df.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df["Species"] = df["Species"].map(
    {
       "Iris-setosa" : 0,
       "Iris-versicolor" : 1,
       "Iris-virginica" : 2 
    }
)

# %%
print(df["Species"].unique())
# Out:
# [0 1 2]

# %%
Y = df["Species"]

# %%
X = df.drop("Species", axis=1)

# %%
X.shape
# Out:
# (150, 4)

# %%
Y.shape
# Out:
# (150,)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(
    X,
    Y, 
    test_size = 0.20,
    random_state = 43
)

# %%
X_train.shape
# Out:
# (120, 4)

# %%
Y_train.shape
# Out:
# (120,)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
print(X_train[:5])
# Out:
# [[-0.2274748  -0.37148923  0.21112983  0.07952174]
#  [-0.97193776  1.68598957 -1.36868691 -1.26450766]
#  [-1.09601493 -1.74314176 -0.31547575 -0.32368708]
#  [-0.97193776 -1.28592425 -0.49101094 -0.18928414]
#  [ 1.01329682 -1.28592425  1.14731753  0.75153644]]

# %%
pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in c:\users\cxash\anaconda\lib\site-packages (2.21.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\cxash\anaconda\lib\site-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\cxash\anaconda\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=25.9.23 in c:\users\cxash\anaconda\lib\site-packages (from tensorflow) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\cxash\anaconda\lib\site-packages (from tensorflow) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in c:\users\cxash\anaconda\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\cxash\anaconda\lib\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in c:\users\cxash\anaconda\lib\site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in c:\users\cxash\anaconda\lib\site-packages (from tensorflow) (25.0)
# Requirement already satisfied: protobuf<8.0.0,>=6.31.1 in c:\users\cxash\anaconda\lib\site-packages (from tensorflow) (7.35.0)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\cxash\anaconda\lib\site-packages (from tensorflow) (2.34.2)
# Requirement already satisfied: setuptools in c:\users\cxash\anaconda\lib\site-packages (from tensorflow) (80.9.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\cxash\anaconda\lib\site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\cxash\anaconda\lib\site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in c:\users\cxash\anaconda\lib\site-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\cxash\anaconda\lib\site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\cxash\anaconda\lib\site-packages (from tensorflow) (1.81.0)
# Requirement already satisfied: keras>=3.12.0 in c:\users\cxash\anaconda\lib\site-packages (from tensorflow) (3.14.1)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\cxash\anaconda\lib\site-packages (from tensorflow) (2.3.5)
# Requirement already satisfied: h5py<3.15.0,>=3.11.0 in c:\users\cxash\anaconda\lib\site-packages (from tensorflow) (3.14.0)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in c:\users\cxash\anaconda\lib\site-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\cxash\anaconda\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\cxash\anaconda\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.11)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\cxash\anaconda\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2.5.0)
# Requirement already satisfied: certifi>=2023.5.7 in c:\users\cxash\anaconda\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2025.11.12)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\cxash\anaconda\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in c:\users\cxash\anaconda\lib\site-packages (from keras>=3.12.0->tensorflow) (14.2.0)
# Requirement already satisfied: namex in c:\users\cxash\anaconda\lib\site-packages (from keras>=3.12.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in c:\users\cxash\anaconda\lib\site-packages (from keras>=3.12.0->tensorflow) (0.19.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\cxash\anaconda\lib\site-packages (from rich->keras>=3.12.0->tensorflow) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\cxash\anaconda\lib\site-packages (from rich->keras>=3.12.0->tensorflow) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\cxash\anaconda\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.12.0->tensorflow) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import tensorflow as tf

# %%
from tensorflow.keras.models import Sequential

# %%
from tensorflow.keras.layers import Dense

# %%
model = Sequential([
    Dense(16, activation="relu", input_shape=(X_train.shape[1],)), 
    Dense(8, activation="relu"),
    Dense(3, activation="sigmoid")
])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_3 (Dense)                      │ (None, 16)                  │              80 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 8)                   │             136 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 3)                   │              27 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 243 (972.00 B)
#  Trainable params: 243 (972.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %%
model.fit(
    X_train,
    Y_train,
    epochs=20, #repeation
    batch_size=32,
    validation_split=0.2,
    )
# Out:
# Epoch 1/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 225ms/step - accuracy: 0.3854 - loss: 1.0332 - val_accuracy: 0.3750 - val_loss: 1.0436
# Epoch 2/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.3958 - loss: 1.0119 - val_accuracy: 0.3750 - val_loss: 1.0266
# Epoch 3/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.4062 - loss: 0.9943 - val_accuracy: 0.3750 - val_loss: 1.0105
# Epoch 4/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.4271 - loss: 0.9751 - val_accuracy: 0.3750 - val_loss: 0.9949
# Epoch 5/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.4583 - loss: 0.9564 - val_accuracy: 0.3750 - val_loss: 0.9797
# Epoch 6/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.5000 - loss: 0.9396 - val_accuracy: 0.3750 - val_loss: 0.9647
# Epoch 7/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.5417 - loss: 0.9230 - val_accuracy: 0.4167 - val_loss: 0.9500
# Epoch 8/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.5729 - loss: 0.9075 - val_accuracy: 0.4167 - val_loss: 0.9355
# Epoch 9/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.5938 - loss: 0.8917 - val_accuracy: 0.4167 - val_loss: 0.9218
# Epoch 10/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.6042 - loss: 0.8774 - val_accuracy: 0.4583 - val_loss: 0.9088
# Epoch 11/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.6562 - loss: 0.8636 - val_accuracy: 0.4583 - val_loss: 0.8963
# Epoch 12/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.6562 - loss: 0.8511 - val_accuracy: 0.5000 - val_loss: 0.8845
# Epoch 13/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.6771 - loss: 0.8386 - val_accuracy: 0.5000 - val_loss: 0.8735
# Epoch 14/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.7188 - loss: 0.8269 - val_accuracy: 0.5000 - val_loss: 0.8632
# Epoch 15/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.7188 - loss: 0.8164 - val_accuracy: 0.5000 - val_loss: 0.8536
# Epoch 16/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.7188 - loss: 0.8064 - val_accuracy: 0.5000 - val_loss: 0.8444
# Epoch 17/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.7396 - loss: 0.7962 - val_accuracy: 0.5000 - val_loss: 0.8358
# Epoch 18/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.7396 - loss: 0.7870 - val_accuracy: 0.5417 - val_loss: 0.8275
# Epoch 19/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.7500 - loss: 0.7781 - val_accuracy: 0.5417 - val_loss: 0.8196
# Epoch 20/20
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.7500 - loss: 0.7694 - val_accuracy: 0.5833 - val_loss: 0.8121

# %%
loss,accuracy=model.evaluate(
    X_test,
    Y_test
)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.7333 - loss: 0.6604

# %%
print(loss)
print(accuracy)
# Out:
# 0.6604099869728088
# 0.7333333492279053

# %%
print(X_train.dtype)
print(Y_train.dtype)
# Out:
# float64
# int64

# %%
prediction=model.predict(X_test)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step

# %%
prediction
# Out:
# array([[0.9343184 , 0.63051057, 0.64745307],
#        [0.95111334, 0.6177802 , 0.7099006 ],
#        [0.48582053, 0.4726852 , 0.53162485],
#        [0.47846618, 0.50422645, 0.50670904],
#        [0.52008903, 0.43510544, 0.5986572 ],
#        [0.9414398 , 0.61558497, 0.6921865 ],
#        [0.48393252, 0.48999286, 0.5186157 ],
#        [0.48288053, 0.50070965, 0.5113164 ],
#        [0.46795166, 0.49401292, 0.50735843],
#        [0.5537838 , 0.5378951 , 0.48913747],
#        [0.9577759 , 0.6505343 , 0.64597327],
#        [0.48830846, 0.47583804, 0.5374855 ],
#        [0.5108261 , 0.42547143, 0.59507567],
#        [0.9607069 , 0.62711525, 0.70307606],
#        [0.4851756 , 0.48866755, 0.5204331 ],
#        [0.48462057, 0.4941459 , 0.51661646],
#        [0.9534735 , 0.60850585, 0.762767  ],
#        [0.92772734, 0.63738453, 0.63157976],
#        [0.47324187, 0.4282685 , 0.55515003],
#        [0.5554085 , 0.46234176, 0.55936736],
#        [0.9286813 , 0.63204426, 0.6481669 ],
#        [0.92689556, 0.63306236, 0.6322107 ],
#        [0.918405  , 0.6318215 , 0.62895715],
#        [0.49057627, 0.49125233, 0.5229552 ],
#        [0.4824983 , 0.47277707, 0.5285914 ],
#        [0.5002874 , 0.41279244, 0.5917771 ],
#        [0.95050204, 0.6157443 , 0.70888376],
#        [0.54230124, 0.50605196, 0.5254737 ],
#        [0.95751387, 0.64031714, 0.68030834],
#        [0.93943614, 0.60633385, 0.7201765 ]], dtype=float32)

# %%
import numpy as np

predicted_classes = np.argmax(prediction, axis=1)

print(predicted_classes[:10])
# Out:
# [0 0 2 2 2 0 2 2 2 0]

# %%
print(Y_test[:5])
# Out:
# [[0.]
#  [0.]
#  [2.]
#  [1.]
#  [2.]]

# %%
#single flower prediction
sample = X_test[:1]

prediction = model.predict(sample)

print(prediction)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# [[0.9343184  0.63051057 0.64745307]]

# %%
print(np.argmax(prediction))
# Out:
# 0

# %%
print(f"Accuracy: {accuracy*100:.2f}%")
# Out:
# Accuracy: 73.33%
